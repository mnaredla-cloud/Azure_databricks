# %% [markdown]
# <a href="https://colab.research.google.com/github/mnaredla-cloud/Azure_databricks/blob/main/1)Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##### Sentiment_Analysis  #####

#For the given input, it gives either positive or Negative Feedback

# %%
from transformers import pipeline
result = pipeline(task="sentiment-analysis")
result("I like this movie")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9998509883880615}]

# %%
from transformers import pipeline #from transformers library importing pipeline API
classifier = pipeline(task = "sentiment-analysis") #
review = "This is a very good movie"
result = classifier(review)
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9998689889907837}]

# %%
from transformers import pipeline
classifier = pipeline(task = "sentiment-analysis")
review = "This is one of the worst movie"
result = classifier(review)
print(result)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# [{'label': 'NEGATIVE', 'score': 0.9997538924217224}]
